# %%
# !pip install powerbiclient
# Out:
# Collecting powerbiclient
#   Using cached powerbiclient-3.1.1-py2.py3-none-any.whl (684 kB)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from powerbiclient) (7.6.3)
# Collecting msal>=1.8.0
#   Downloading msal-1.24.0-py2.py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.3/91.3 kB 345.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.25.1 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from powerbiclient) (2.25.1)
# Requirement already satisfied: pandas in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from powerbiclient) (1.2.4)
# Collecting jupyter-ui-poll>=0.1.2
#   Using cached jupyter_ui_poll-0.2.2-py2.py3-none-any.whl (9.0 kB)
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 3.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->powerbiclient) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->powerbiclient) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->powerbiclient) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->powerbiclient) (5.3.4)
# Requirement already satisfied: ipython>=4.0.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->powerbiclient) (7.22.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->powerbiclient) (5.0.5)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: cryptography<44,>=0.6 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from msal>=1.8.0->powerbiclient) (3.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.1->powerbiclient) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.1->powerbiclient) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.1->powerbiclient) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.25.1->powerbiclient) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from pandas->powerbiclient) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from pandas->powerbiclient) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from pandas->powerbiclient) (1.20.1)
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: cffi>=1.12 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from cryptography<44,>=0.6->msal>=1.8.0->powerbiclient) (1.14.5)
# Requirement already satisfied: appnope in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (0.1.2)
# Requirement already satisfied: jupyter-client in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (6.1)
# Requirement already satisfied: decorator in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (5.0.6)
# Requirement already satisfied: pygments in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (0.17.2)
# Requirement already satisfied: backcall in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (62.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->powerbiclient) (3.2.0)
# Requirement already satisfied: ipython-genutils in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->powerbiclient) (0.2.0)
# Requirement already satisfied: jupyter-core in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->powerbiclient) (4.7.1)
# Requirement already satisfied: six>=1.5 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->powerbiclient) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (6.3.0)
# Requirement already satisfied: pycparser in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12->cryptography<44,>=0.6->msal>=1.8.0->powerbiclient) (2.20)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (0.7.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->powerbiclient) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->powerbiclient) (20.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (1.5.0)
# Requirement already satisfied: prometheus-client in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.10.1)
# Requirement already satisfied: nbconvert in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (6.0.7)
# Requirement already satisfied: jinja2 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (2.11.3)
# Requirement already satisfied: argon2-cffi in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (20.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->powerbiclient) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.3)
# Requirement already satisfied: testpath in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.4.4)
# Requirement already satisfied: defusedxml in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.7.1)
# Requirement already satisfied: bleach in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (1.4.3)
# Requirement already satisfied: async-generator in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (1.5.1)
# Requirement already satisfied: packaging in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (20.9)
# Requirement already satisfied: webencodings in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/badboyalex/opt/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->powerbiclient) (2.4.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285397 sha256=466a565099dd5d0b3d1712babee581de6943a88351d0aaf02e97b9e4905f9dc2
#   Stored in directory: /Users/badboyalex/Library/Caches/pip/wheels/07/9f/04/fc2c478c8c87334f0ff48e86fa7d8c2a814f9df5dc21d79b7e
# Successfully built pyspark
# Installing collected packages: py4j, pyspark, PyJWT, jupyter-ui-poll, msal, powerbiclient
# Successfully installed PyJWT-2.8.0 jupyter-ui-poll-0.2.2 msal-1.24.0 powerbiclient-3.1.1 py4j-0.10.9.7 pyspark-3.4.1
# WARNING: There was an error checking the latest version of pip.

# %%
from powerbiclient import QuickVisualize, get_dataset_config, Report
from powerbiclient.authentication import DeviceCodeLoginAuthentication

import pandas as pd

# %%
device_auth = DeviceCodeLoginAuthentication()
# Out:
# Performing device flow authentication. Please follow the instructions below.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CRHUXF9RP to authenticate.
#
# Device flow authentication successfully completed.
# You are now logged in .
#
# The result should be passed only to trusted code in your notebook.

# %%
# Import sample csv as a pandas DataFrame
df = pd.read_csv('dataset.csv')

#Display DataFrame
df.head()
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
# 3  YAK/S/00004         Commercial Sales and Marketing  First Degree or HND
# 4  YAK/S/00006               Information and Strategy  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
# 3    Male        Agency and others                   3           1982
# 4    Male  Direct Internal process                   3           1990
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# 0                    12.5                 2011            1               0
# 1                    12.5                 2015            0               0
# 2                     7.5                 2012            0               0
# 3                     2.5                 2009            0               0
# 4                     7.5                 2012            0               0
#
#    Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 0                      41         ANAMBRA               No        Married
# 1                      52         ANAMBRA              Yes        Married
# 2                      42         KATSINA              Yes        Married
# 3                      42           NIGER              Yes         Single
# 4                      77       AKWA IBOM              Yes        Married
#
#   Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 0                       No                                  No
# 1                       No                                  No
# 2                       No                                  No
# 3                       No                                  No
# 4                       No                                  No
#
#   No_of_previous_employers  Promoted_or_Not
# 0                        0                0
# 1                        0                0
# 2                        0                0
# 3                        1                0
# 4                        1                0

# %%
# create a power bi report from your data
PBI_visualize = QuickVisualize(get_dataset_config(df),auth=device_auth)

# %%
QuickVisualize(get_dataset_config(df),auth=device_auth)
# Out:
# QuickVisualize()

# %%
#Render new report
PBI_visualize
# Out:
# QuickVisualize()

# %%
df
# Out:
#         EmployeeNo                                     Division  \
# 0      YAK/S/00001               Commercial Sales and Marketing
# 1      YAK/S/00002        Customer Support and Field Operations
# 2      YAK/S/00003               Commercial Sales and Marketing
# 3      YAK/S/00004               Commercial Sales and Marketing
# 4      YAK/S/00006                     Information and Strategy
# ...            ...                                          ...
# 38307  YAK/S/54802  Information Technology and Solution Support
# 38308  YAK/S/54805        Customer Support and Field Operations
# 38309  YAK/S/54806                     Information and Strategy
# 38310  YAK/S/54807               Commercial Sales and Marketing
# 38311  YAK/S/54808                         People/HR Management
#
#              Qualification  Gender   Channel_of_Recruitment  \
# 0         MSc, MBA and PhD  Female  Direct Internal process
# 1      First Degree or HND    Male        Agency and others
# 2      First Degree or HND    Male  Direct Internal process
# 3      First Degree or HND    Male        Agency and others
# 4      First Degree or HND    Male  Direct Internal process
# ...                    ...     ...                      ...
# 38307  First Degree or HND  Female  Direct Internal process
# 38308     MSc, MBA and PhD  Female        Agency and others
# 38309  First Degree or HND    Male        Agency and others
# 38310                  NaN    Male  Direct Internal process
# 38311  First Degree or HND    Male        Agency and others
#
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# 0                       2           1986                    12.5
# 1                       2           1991                    12.5
# 2                       2           1987                     7.5
# 3                       3           1982                     2.5
# 4                       3           1990                     7.5
# ...                   ...            ...                     ...
# 38307                   2           1990                     0.0
# 38308                   2           1984                     5.0
# 38309                   2           1994                    12.5
# 38310                   2           1992                     2.5
# 38311                   2           1994                     2.5
#
#        Year_of_recruitment  Targets_met  Previous_Award  \
# 0                     2011            1               0
# 1                     2015            0               0
# 2                     2012            0               0
# 3                     2009            0               0
# 4                     2012            0               0
# ...                    ...          ...             ...
# 38307                 2018            0               0
# 38308                 2013            0               0
# 38309                 2016            1               0
# 38310                 2017            0               0
# 38311                 2014            0               0
#
#        Training_score_average State_Of_Origin Foreign_schooled Marital_Status  \
# 0                          41         ANAMBRA               No        Married
# 1                          52         ANAMBRA              Yes        Married
# 2                          42         KATSINA              Yes        Married
# 3                          42           NIGER              Yes         Single
# 4                          77       AKWA IBOM              Yes        Married
# ...                       ...             ...              ...            ...
# 38307                      70           LAGOS              Yes        Married
# 38308                      48             IMO              Yes        Married
# 38309                      71         ANAMBRA               No        Married
# 38310                      37           KWARA              Yes        Married
# 38311                      41           KWARA              Yes         Single
#
#       Past_Disciplinary_Action Previous_IntraDepartmental_Movement  \
# 0                           No                                  No
# 1                           No                                  No
# 2                           No                                  No
# 3                           No                                  No
# 4                           No                                  No
# ...                        ...                                 ...
# 38307                       No                                  No
# 38308                       No                                  No
# 38309                       No                                  No
# 38310                       No                                  No
# 38311                       No                                  No
#
#       No_of_previous_employers  Promoted_or_Not
# 0                            0                0
# 1                            0                0
# 2                            0                0
# 3                            1                0
# 4                            1                0
# ...                        ...              ...
# 38307                        0                0
# 38308                        1                0
# 38309                        3                0
# 38310                        1                0
# 38311                        2                0
#
# [38312 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')
